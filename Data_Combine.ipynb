# %% [markdown]
# ##### If a pitcher is playing in the National League, then they will have at bats... Hitters may have some pitching stats if their team is down a lot... Make data based off primary position?
#
# ##### To do:
# ###### - Fix Appearances Clean to have primary position based on max amount of games / standings at a position
# ###### - Remove Primary Position Pitchers from the Batting info and create a new CSV to show only pitchers with combined information
# ###### - Remove Primary Position =/ Pitchers from the Pitching info and create a new CSV to show only fielders with combined information
#
# ##### Elgibility for HOF:
# ###### - Played at least 10 seasons
# ###### - Retired at least 5 seasons
#
# ##### To Do:
# ###### - Add Column to show years since final game to cleaning files of pitchers and batters
# ###### - Create a function that takes players with season > 10 years and retired years > 5 years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_Clean_Batting = pd.read_csv('Clean CSV\Clean_Batting.csv', encoding="ISO-8859-1")
df_Clean_HOF = pd.read_csv('Clean CSV\Clean_HOF.csv', encoding= "ISO-8859-1")
df_Clean_Pitching = pd.read_csv('Clean CSV\Clean_Pitching.csv', encoding="ISO-8859-1")
df_Clean_Players = pd.read_csv('Clean CSV\Clean_Players.csv', encoding="ISO-8859-1")
df_Clean_Positions = pd.read_csv('Clean CSV\Clean_Positions.csv', encoding="ISO-8859-1")

# %%
nulls = df_Clean_Batting.isnull().sum()
nulls[nulls > 0]
# Out:
# Series([], dtype: int64)

# %%
nulls = df_Clean_HOF.isnull().sum()
nulls[nulls > 0]
# Out:
# Series([], dtype: int64)

# %%
nulls = df_Clean_Pitching.isnull().sum()
nulls[nulls > 0]
# Out:
# Series([], dtype: int64)

# %%
nulls = df_Clean_Players.isnull().sum()
nulls[nulls > 0]
# Out:
# nameFirst          37
# weight            816
# height            736
# bats             1181
# throws            977
# finalGame         210
# Retired_Years     210
# dtype: int64

# %% [markdown]
# I think the best course of action would to be leave it at Zero?? Ask TAs on Monday... Final Game & Retired Years are most likely current players...

# %%
# hall eligibility function
def eligible_for_hall(row):
    if (row['Seasons']>=10) & (row['Retired_Years']>=5):
        return 'eligible'
    else:
        return 'not_eligible'

# %%
nulls = df_Clean_Positions.isnull().sum()
nulls[nulls > 0]
# Out:
# Series([], dtype: int64)

# %%
# Merge Demo + Batting
df_Position_Players = pd.merge(df_Clean_Batting, df_Clean_Players, on='playerID', how='left')

# %%
df_Position_Players
# Out:
#         playerID  Seasons  Games  At_Bats  Runs  Hits  Doubles  Triples  \
# 0      aardsda01        9    331        4     0     0        0        0
# 1      aaronha01       23   3298    12364  2174  3771      624       98
# 2      aaronto01        7    437      944   102   216       42        6
# 3       aasedo01       13    448        5     0     0        0        0
# 4       abadan01        3     15       21     1     2        0        0
# ...          ...      ...    ...      ...   ...   ...      ...      ...
# 20161   zupofr01        3     16       18     3     3        1        0
# 20162  zuvelpa01        9    209      491    41   109       17        2
# 20163  zuverge01       12    266      142     5    21        2        1
# 20164  zwilldu01        4    366     1280   167   364       76       15
# 20165   zychto01        3     70        0     0     0        0        0
#
#        Homeruns    RBIs  ...  Sac_Flys  Double_Plays  nameFirst  nameLast  \
# 0             0     0.0  ...       0.0           0.0      David   Aardsma
# 1           755  2297.0  ...     121.0         328.0       Hank     Aaron
# 2            13    94.0  ...       6.0          36.0     Tommie     Aaron
# 3             0     0.0  ...       0.0           0.0        Don      Aase
# 4             0     0.0  ...       0.0           1.0       Andy      Abad
# ...         ...     ...  ...       ...           ...        ...       ...
# 20161         0     0.0  ...       0.0           0.0      Frank      Zupo
# 20162         2    20.0  ...       0.0           8.0       Paul   Zuvella
# 20163         0     7.0  ...       0.0           3.0     George  Zuverink
# 20164        30   202.0  ...       0.0           0.0      Dutch  Zwilling
# 20165         0     0.0  ...       0.0           0.0       Tony      Zych
#
#        weight  height  bats  throws   finalGame Retired_Years
# 0       215.0    75.0     R       R  2015-08-23      6.690411
# 1       180.0    72.0     R       R  1976-10-03     45.602740
# 2       190.0    75.0     R       R  1971-09-26     50.627397
# 3       190.0    75.0     R       R  1990-10-03     31.594521
# 4       184.0    73.0     L       L  2006-04-13     16.057534
# ...       ...     ...   ...     ...         ...           ...
# 20161   182.0    71.0     L       R  1961-05-09     61.016438
# 20162   173.0    72.0     R       R  1991-05-02     31.016438
# 20163   195.0    76.0     R       R  1959-06-15     62.917808
# 20164   160.0    66.0     L       L  1916-07-12    105.871233
# 20165   190.0    75.0     R       R  2017-08-19      4.698630
#
# [20166 rows x 26 columns]

# %%
# Merge Postion Players + HOF
df_Position_Players_HOF = pd.merge(df_Position_Players, df_Clean_HOF, on='playerID', how='left')

# %%
df_Position_Players_HOF
# Out:
#         playerID  Seasons  Games  At_Bats  Runs  Hits  Doubles  Triples  \
# 0      aardsda01        9    331        4     0     0        0        0
# 1      aaronha01       23   3298    12364  2174  3771      624       98
# 2      aaronto01        7    437      944   102   216       42        6
# 3       aasedo01       13    448        5     0     0        0        0
# 4       abadan01        3     15       21     1     2        0        0
# ...          ...      ...    ...      ...   ...   ...      ...      ...
# 23000   zupofr01        3     16       18     3     3        1        0
# 23001  zuvelpa01        9    209      491    41   109       17        2
# 23002  zuverge01       12    266      142     5    21        2        1
# 23003  zwilldu01        4    366     1280   167   364       76       15
# 23004   zychto01        3     70        0     0     0        0        0
#
#        Homeruns    RBIs  ...  nameLast  weight  height  bats  throws  \
# 0             0     0.0  ...   Aardsma   215.0    75.0     R       R
# 1           755  2297.0  ...     Aaron   180.0    72.0     R       R
# 2            13    94.0  ...     Aaron   190.0    75.0     R       R
# 3             0     0.0  ...      Aase   190.0    75.0     R       R
# 4             0     0.0  ...      Abad   184.0    73.0     L       L
# ...         ...     ...  ...       ...     ...     ...   ...     ...
# 23000         0     0.0  ...      Zupo   182.0    71.0     L       R
# 23001         2    20.0  ...   Zuvella   173.0    72.0     R       R
# 23002         0     7.0  ...  Zuverink   195.0    76.0     R       R
# 23003        30   202.0  ...  Zwilling   160.0    66.0     L       L
# 23004         0     0.0  ...      Zych   190.0    75.0     R       R
#
#         finalGame  Retired_Years  yearID inducted category
# 0      2015-08-23       6.690411     NaN      NaN      NaN
# 1      1976-10-03      45.602740  1982.0        Y   Player
# 2      1971-09-26      50.627397     NaN      NaN      NaN
# 3      1990-10-03      31.594521     NaN      NaN      NaN
# 4      2006-04-13      16.057534     NaN      NaN      NaN
# ...           ...            ...     ...      ...      ...
# 23000  1961-05-09      61.016438     NaN      NaN      NaN
# 23001  1991-05-02      31.016438     NaN      NaN      NaN
# 23002  1959-06-15      62.917808     NaN      NaN      NaN
# 23003  1916-07-12     105.871233     NaN      NaN      NaN
# 23004  2017-08-19       4.698630     NaN      NaN      NaN
#
# [23005 rows x 29 columns]

# %%
df_Position_Players_HOF.columns
# Out:
# Index(['playerID', 'Seasons', 'Games', 'At_Bats', 'Runs', 'Hits', 'Doubles',
#        'Triples', 'Homeruns', 'RBIs', 'Stolen_Bases', 'Walks', 'Strike_Outs',
#        'Intentional_Walks', 'Hit_by_Pitch', 'Sac_Hits', 'Sac_Flys',
#        'Double_Plays', 'nameFirst', 'nameLast', 'weight', 'height', 'bats',
#        'throws', 'finalGame', 'Retired_Years', 'yearID', 'inducted',
#        'category'],
#       dtype='object')

# %%
df_Position_Players_HOF = df_Position_Players_HOF[['playerID',
                                                   'nameFirst', 
                                                   'nameLast', 
                                                   'weight', 
                                                   'height', 
                                                   'bats',
                                                   'throws',
                                                   'Seasons', 
                                                   'Games', 
                                                   'At_Bats', 
                                                   'Runs', 
                                                   'Hits', 
                                                   'Doubles',
                                                   'Triples', 
                                                   'Homeruns', 
                                                   'RBIs', 
                                                   'Stolen_Bases', 
                                                   'Walks',
                                                   'Intentional_Walks', 
                                                   'Strike_Outs',
                                                   'Hit_by_Pitch', 
                                                   'Sac_Hits', 
                                                   'Sac_Flys',
                                                   'Double_Plays',
                                                   'finalGame', 
                                                   'Retired_Years', 
                                                   'inducted',
                                                   'yearID']]

# %%
df_Position_Players_HOF
# Out:
#         playerID nameFirst  nameLast  weight  height bats throws  Seasons  \
# 0      aardsda01     David   Aardsma   215.0    75.0    R      R        9
# 1      aaronha01      Hank     Aaron   180.0    72.0    R      R       23
# 2      aaronto01    Tommie     Aaron   190.0    75.0    R      R        7
# 3       aasedo01       Don      Aase   190.0    75.0    R      R       13
# 4       abadan01      Andy      Abad   184.0    73.0    L      L        3
# ...          ...       ...       ...     ...     ...  ...    ...      ...
# 23000   zupofr01     Frank      Zupo   182.0    71.0    L      R        3
# 23001  zuvelpa01      Paul   Zuvella   173.0    72.0    R      R        9
# 23002  zuverge01    George  Zuverink   195.0    76.0    R      R       12
# 23003  zwilldu01     Dutch  Zwilling   160.0    66.0    L      L        4
# 23004   zychto01      Tony      Zych   190.0    75.0    R      R        3
#
#        Games  At_Bats  ...  Intentional_Walks  Strike_Outs  Hit_by_Pitch  \
# 0        331        4  ...                0.0          2.0           0.0
# 1       3298    12364  ...              293.0       1383.0          32.0
# 2        437      944  ...                3.0        145.0           0.0
# 3        448        5  ...                0.0          3.0           0.0
# 4         15       21  ...                0.0          5.0           0.0
# ...      ...      ...  ...                ...          ...           ...
# 23000     16       18  ...                0.0          6.0           0.0
# 23001    209      491  ...                1.0         50.0           2.0
# 23002    266      142  ...                0.0         39.0           0.0
# 23003    366     1280  ...                0.0        155.0           4.0
# 23004     70        0  ...                0.0          0.0           0.0
#
#        Sac_Hits  Sac_Flys  Double_Plays   finalGame  Retired_Years  inducted  \
# 0           1.0       0.0           0.0  2015-08-23       6.690411       NaN
# 1          21.0     121.0         328.0  1976-10-03      45.602740         Y
# 2           9.0       6.0          36.0  1971-09-26      50.627397       NaN
# 3           0.0       0.0           0.0  1990-10-03      31.594521       NaN
# 4           0.0       0.0           1.0  2006-04-13      16.057534       NaN
# ...         ...       ...           ...         ...            ...       ...
# 23000       0.0       0.0           0.0  1961-05-09      61.016438       NaN
# 23001      18.0       0.0           8.0  1991-05-02      31.016438       NaN
# 23002      16.0       0.0           3.0  1959-06-15      62.917808       NaN
# 23003      31.0       0.0           0.0  1916-07-12     105.871233       NaN
# 23004       0.0       0.0           0.0  2017-08-19       4.698630       NaN
#
#        yearID
# 0         NaN
# 1      1982.0
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 23000     NaN
# 23001     NaN
# 23002     NaN
# 23003     NaN
# 23004     NaN
#
# [23005 rows x 28 columns]

# %%
df_Postion_Players_Complete = pd.merge(df_Position_Players_HOF, df_Clean_Positions, on='playerID', how='left')

# %%
df_Postion_Players_Complete
# Out:
#         playerID nameFirst  nameLast  weight  height bats throws  Seasons  \
# 0      aardsda01     David   Aardsma   215.0    75.0    R      R        9
# 1      aaronha01      Hank     Aaron   180.0    72.0    R      R       23
# 2      aaronto01    Tommie     Aaron   190.0    75.0    R      R        7
# 3       aasedo01       Don      Aase   190.0    75.0    R      R       13
# 4       abadan01      Andy      Abad   184.0    73.0    L      L        3
# ...          ...       ...       ...     ...     ...  ...    ...      ...
# 23000   zupofr01     Frank      Zupo   182.0    71.0    L      R        3
# 23001  zuvelpa01      Paul   Zuvella   173.0    72.0    R      R        9
# 23002  zuverge01    George  Zuverink   195.0    76.0    R      R       12
# 23003  zwilldu01     Dutch  Zwilling   160.0    66.0    L      L        4
# 23004   zychto01      Tony      Zych   190.0    75.0    R      R        3
#
#        Games  At_Bats  ...  FirstBase  SecondBase  ThirdBase  ShortStop  \
# 0        331        4  ...          0           0          0          0
# 1       3298    12364  ...        210          43          7          0
# 2        437      944  ...        232           7         10          0
# 3        448        5  ...          0           0          0          0
# 4         15       21  ...          8           0          0          0
# ...      ...      ...  ...        ...         ...        ...        ...
# 23000     16       18  ...          0           0          0          0
# 23001    209      491  ...          0          55         14        133
# 23002    266      142  ...          0           0          0          0
# 23003    366     1280  ...          3           0          0          0
# 23004     70        0  ...          0           0          0          0
#
#        LeftField  CenterField  RightField  Outfield     DH  Primary_Position
# 0              0            0           0         0    0.0           Pitcher
# 1            315          308        2174      2760  201.0          Outfield
# 2            135            1           2       137    0.0         FirstBase
# 3              0            0           0         0    0.0           Pitcher
# 4              0            0           1         1    0.0         FirstBase
# ...          ...          ...         ...       ...    ...               ...
# 23000          0            0           0         0    0.0           Catcher
# 23001          0            0           0         0    3.0         ShortStop
# 23002          0            0           0         0    0.0           Pitcher
# 23003          0          335           5       339    0.0          Outfield
# 23004          0            0           0         0    0.0           Pitcher
#
# [23005 rows x 42 columns]

# %%
nulls = df_Postion_Players_Complete.isnull().sum()
nulls[nulls > 0]
# Out:
# nameFirst           37
# weight             718
# height             636
# bats              1073
# throws             868
# finalGame            7
# Retired_Years        7
# inducted         18965
# yearID           18965
# dtype: int64

# %%
df_Postion_Players_Complete.fillna(0, inplace=True)

# %%
df_Non_Pitchers = df_Postion_Players_Complete[df_Postion_Players_Complete['Primary_Position']!='Pitcher']

# %%
df_Non_Pitchers.columns
# Out:
# Index(['playerID', 'nameFirst', 'nameLast', 'weight', 'height', 'bats',
#        'throws', 'Seasons', 'Games', 'At_Bats', 'Runs', 'Hits', 'Doubles',
#        'Triples', 'Homeruns', 'RBIs', 'Stolen_Bases', 'Walks',
#        'Intentional_Walks', 'Strike_Outs', 'Hit_by_Pitch', 'Sac_Hits',
#        'Sac_Flys', 'Double_Plays', 'finalGame', 'Retired_Years', 'inducted',
#        'yearID', 'Total_Games', 'Games_Started', 'Pitcher', 'Catcher',
#        'FirstBase', 'SecondBase', 'ThirdBase', 'ShortStop', 'LeftField',
#        'CenterField', 'RightField', 'Outfield', 'DH', 'Primary_Position'],
#       dtype='object')

# %%
#Remove Extra Columns
df_Non_Pitchers = df_Non_Pitchers.drop(columns=['Pitcher', 
                                                'Catcher', 
                                                'FirstBase', 
                                                'SecondBase', 
                                                'ThirdBase', 
                                                'ShortStop', 
                                                'LeftField',
                                                'CenterField', 
                                                'RightField', 
                                                'Outfield', 
                                                'DH'])

# %%
df_Non_Pitchers
# Out:
#         playerID nameFirst     nameLast  weight  height bats throws  Seasons  \
# 1      aaronha01      Hank        Aaron   180.0    72.0    R      R       23
# 2      aaronto01    Tommie        Aaron   190.0    75.0    R      R        7
# 4       abadan01      Andy         Abad   184.0    73.0    L      L        3
# 6      abadijo01      John       Abadie   192.0    72.0    R      R        3
# 7      abbated01        Ed  Abbaticchio   170.0    71.0    R      R       11
# ...          ...       ...          ...     ...     ...  ...    ...      ...
# 22998  zuninmi01      Mike       Zunino   235.0    74.0    R      R        9
# 22999  zupcibo01       Bob       Zupcic   220.0    76.0    R      R        6
# 23000   zupofr01     Frank         Zupo   182.0    71.0    L      R        3
# 23001  zuvelpa01      Paul      Zuvella   173.0    72.0    R      R        9
# 23003  zwilldu01     Dutch     Zwilling   160.0    66.0    L      L        4
#
#        Games  At_Bats  ...  Sac_Hits  Sac_Flys  Double_Plays   finalGame  \
# 1       3298    12364  ...      21.0     121.0         328.0  1976-10-03
# 2        437      944  ...       9.0       6.0          36.0  1971-09-26
# 4         15       21  ...       0.0       0.0           1.0  2006-04-13
# 6         12       49  ...       0.0       0.0           0.0  1875-06-10
# 7        855     3044  ...      93.0       0.0           0.0  1910-09-15
# ...      ...      ...  ...       ...       ...           ...         ...
# 22998    814     2559  ...       8.0      12.0          49.0  2021-10-03
# 22999    319      795  ...      20.0       8.0          15.0  1994-08-04
# 23000     16       18  ...       0.0       0.0           0.0  1961-05-09
# 23001    209      491  ...      18.0       0.0           8.0  1991-05-02
# 23003    366     1280  ...      31.0       0.0           0.0  1916-07-12
#
#        Retired_Years  inducted  yearID  Total_Games  Games_Started  \
# 1          45.602740         Y  1982.0         3298         3173.0
# 2          50.627397         0     0.0          437          206.0
# 4          16.057534         0     0.0           15            4.0
# 6         146.986301         0     0.0           12            0.0
# 7         111.698630         0     0.0          857          664.0
# ...              ...       ...     ...          ...            ...
# 22998       0.572603         0     0.0          814          737.0
# 22999      27.756164         0     0.0          319          198.0
# 23000      61.016438         0     0.0           16            1.0
# 23001      31.016438         0     0.0          209          138.0
# 23003     105.871233         0     0.0          367          337.0
#
#        Primary_Position
# 1              Outfield
# 2             FirstBase
# 4             FirstBase
# 6             FirstBase
# 7            SecondBase
# ...                 ...
# 22998           Catcher
# 22999          Outfield
# 23000           Catcher
# 23001         ShortStop
# 23003          Outfield
#
# [12465 rows x 31 columns]

# %%
df_Non_Pitchers['Primary_Position'].replace(['LeftField',
                                             'RightField', 
                                             'CenterField'], 'Outfield', inplace=True)

# %%
df_Non_Pitchers.Primary_Position.value_counts()
# Out:
# Outfield      4668
# Catcher       2149
# ShortStop     1440
# SecondBase    1426
# FirstBase     1349
# ThirdBase     1304
# DH             129
# Name: Primary_Position, dtype: int64

# %%
df_Non_Pitchers['Hall_Eligible'] = df_Non_Pitchers.apply(eligible_for_hall,axis=1)
df_Non_Pitchers.inducted.replace(0, 'N', inplace=True)

# %%
df_Non_Pitchers.playerID.count()
# Out:
# 12465

# %%
df_Non_Pitchers = df_Non_Pitchers.drop_duplicates(['playerID'])

# %%
df_Non_Pitchers.playerID.count()
# Out:
# 10541

# %% [markdown]
# # Pitcher Cleaning Below

# %%
df_Clean_Pitching
# Out:
#         playerID  Seasons  Wins  Losses  Games  Pitch_Starts  Complete_Games  \
# 0      aardsda01        9    16      18    331             0               0
# 1       aasedo01       13    66      60    448            91              22
# 2       abadfe01       12     8      29    400             6               0
# 3      abbeybe01        7    22      40     79            65              52
# 4      abbeych01        1     0       0      1             0               0
# ...          ...      ...   ...     ...    ...           ...             ...
# 10194  zuberbi01       13    43      42    224            65              23
# 10195  zuberty01        2     1       5     54             0               0
# 10196  zumayjo01        5    13      12    171             0               0
# 10197  zuverge01       12    32      36    265            31               9
# 10198   zychto01        3     7       3     70             1               0
#
#        Shutouts  Saves  Outs_Pitched  Hits  Earned_Runs  Home_Runs  Walks  \
# 0             0     69          1011   296          160         41    183
# 1             5     82          3328  1085          468         89    457
# 2             0      2          1045   332          146         43    123
# 3             0      1          1704   686          285         18    192
# 4             0      0             6     6            1          0      0
# ...         ...    ...           ...   ...          ...        ...    ...
# 10194         3      6          2358   767          374         35    468
# 10195         0      0           148    41           29         10     37
# 10196         0      5           629   169           71         18    114
# 10197         2     40          1927   660          253         56    203
# 10198         0      1           218    57           22          3     34
#
#        Strikeouts  Batters_Faced  Games_Finished  Runs_Allowed
# 0             340         1475.0             141           169
# 1             641         4730.0             235           503
# 2             290         1481.0             101           155
# 3             161         2568.0              14           442
# 4               0           12.0               1             3
# ...           ...            ...             ...           ...
# 10194         383         3476.0              90           418
# 10195          55          222.0              14            31
# 10196         210          911.0              35            80
# 10197         223         2746.0             139           296
# 10198          80          309.0              14            24
#
# [10199 rows x 18 columns]

# %%
# Pitchers Combined Demo and Pitching Stats
df_Pitchers_Demo = pd.merge(df_Clean_Pitching,df_Clean_Players, on='playerID',how='left')
df_Pitchers_Demo
# Out:
#         playerID  Seasons  Wins  Losses  Games  Pitch_Starts  Complete_Games  \
# 0      aardsda01        9    16      18    331             0               0
# 1       aasedo01       13    66      60    448            91              22
# 2       abadfe01       12     8      29    400             6               0
# 3      abbeybe01        7    22      40     79            65              52
# 4      abbeych01        1     0       0      1             0               0
# ...          ...      ...   ...     ...    ...           ...             ...
# 10194  zuberbi01       13    43      42    224            65              23
# 10195  zuberty01        2     1       5     54             0               0
# 10196  zumayjo01        5    13      12    171             0               0
# 10197  zuverge01       12    32      36    265            31               9
# 10198   zychto01        3     7       3     70             1               0
#
#        Shutouts  Saves  Outs_Pitched  ...  Games_Finished  Runs_Allowed  \
# 0             0     69          1011  ...             141           169
# 1             5     82          3328  ...             235           503
# 2             0      2          1045  ...             101           155
# 3             0      1          1704  ...              14           442
# 4             0      0             6  ...               1             3
# ...         ...    ...           ...  ...             ...           ...
# 10194         3      6          2358  ...              90           418
# 10195         0      0           148  ...              14            31
# 10196         0      5           629  ...              35            80
# 10197         2     40          1927  ...             139           296
# 10198         0      1           218  ...              14            24
#
#        nameFirst  nameLast  weight  height  bats  throws   finalGame  \
# 0          David   Aardsma   215.0    75.0     R       R  2015-08-23
# 1            Don      Aase   190.0    75.0     R       R  1990-10-03
# 2       Fernando      Abad   235.0    74.0     L       L  2021-10-01
# 3           Bert     Abbey   175.0    71.0     R       R  1896-09-23
# 4        Charlie     Abbey   169.0    68.0     L       L  1897-08-19
# ...          ...       ...     ...     ...   ...     ...         ...
# 10194       Bill     Zuber   195.0    74.0     R       R  1947-09-23
# 10195      Tyler     Zuber   175.0    71.0     R       R  2021-09-30
# 10196       Joel    Zumaya   215.0    75.0     R       R  2010-06-28
# 10197     George  Zuverink   195.0    76.0     R       R  1959-06-15
# 10198       Tony      Zych   190.0    75.0     R       R  2017-08-19
#
#       Retired_Years
# 0          6.690411
# 1         31.594521
# 2          0.578082
# 3        125.682192
# 4        124.778082
# ...             ...
# 10194     74.652055
# 10195      0.580822
# 10196     11.846575
# 10197     62.917808
# 10198      4.698630
#
# [10199 rows x 26 columns]

# %%
df_Pitchers_Demo.columns
# Out:
# Index(['playerID', 'Seasons', 'Wins', 'Losses', 'Games', 'Pitch_Starts',
#        'Complete_Games', 'Shutouts', 'Saves', 'Outs_Pitched', 'Hits',
#        'Earned_Runs', 'Home_Runs', 'Walks', 'Strikeouts', 'Batters_Faced',
#        'Games_Finished', 'Runs_Allowed', 'nameFirst', 'nameLast', 'weight',
#        'height', 'bats', 'throws', 'finalGame', 'Retired_Years'],
#       dtype='object')

# %%
df_Pitchers_Demo_HOF = pd.merge(df_Pitchers_Demo,df_Clean_HOF, on='playerID',how='left')

# %%
df_Pitchers_Demo_HOF
# Out:
#         playerID  Seasons  Wins  Losses  Games  Pitch_Starts  Complete_Games  \
# 0      aardsda01        9    16      18    331             0               0
# 1       aasedo01       13    66      60    448            91              22
# 2       abadfe01       12     8      29    400             6               0
# 3      abbeybe01        7    22      40     79            65              52
# 4      abbeych01        1     0       0      1             0               0
# ...          ...      ...   ...     ...    ...           ...             ...
# 11295  zuberbi01       13    43      42    224            65              23
# 11296  zuberty01        2     1       5     54             0               0
# 11297  zumayjo01        5    13      12    171             0               0
# 11298  zuverge01       12    32      36    265            31               9
# 11299   zychto01        3     7       3     70             1               0
#
#        Shutouts  Saves  Outs_Pitched  ...  nameLast  weight  height  bats  \
# 0             0     69          1011  ...   Aardsma   215.0    75.0     R
# 1             5     82          3328  ...      Aase   190.0    75.0     R
# 2             0      2          1045  ...      Abad   235.0    74.0     L
# 3             0      1          1704  ...     Abbey   175.0    71.0     R
# 4             0      0             6  ...     Abbey   169.0    68.0     L
# ...         ...    ...           ...  ...       ...     ...     ...   ...
# 11295         3      6          2358  ...     Zuber   195.0    74.0     R
# 11296         0      0           148  ...     Zuber   175.0    71.0     R
# 11297         0      5           629  ...    Zumaya   215.0    75.0     R
# 11298         2     40          1927  ...  Zuverink   195.0    76.0     R
# 11299         0      1           218  ...      Zych   190.0    75.0     R
#
#        throws   finalGame  Retired_Years  yearID inducted category
# 0           R  2015-08-23       6.690411     NaN      NaN      NaN
# 1           R  1990-10-03      31.594521     NaN      NaN      NaN
# 2           L  2021-10-01       0.578082     NaN      NaN      NaN
# 3           R  1896-09-23     125.682192     NaN      NaN      NaN
# 4           L  1897-08-19     124.778082     NaN      NaN      NaN
# ...       ...         ...            ...     ...      ...      ...
# 11295       R  1947-09-23      74.652055     NaN      NaN      NaN
# 11296       R  2021-09-30       0.580822     NaN      NaN      NaN
# 11297       R  2010-06-28      11.846575     NaN      NaN      NaN
# 11298       R  1959-06-15      62.917808     NaN      NaN      NaN
# 11299       R  2017-08-19       4.698630     NaN      NaN      NaN
#
# [11300 rows x 29 columns]

# %%
df_Pitchers_Demo_HOF.columns
# Out:
# Index(['playerID', 'Seasons', 'Wins', 'Losses', 'Games', 'Pitch_Starts',
#        'Complete_Games', 'Shutouts', 'Saves', 'Outs_Pitched', 'Hits',
#        'Earned_Runs', 'Home_Runs', 'Walks', 'Strikeouts', 'Batters_Faced',
#        'Games_Finished', 'Runs_Allowed', 'nameFirst', 'nameLast', 'weight',
#        'height', 'bats', 'throws', 'finalGame', 'Retired_Years', 'yearID',
#        'inducted', 'category'],
#       dtype='object')

# %%
df_Pitchers_Demo_HOF = df_Pitchers_Demo_HOF [['playerID',
                                              'nameFirst', 
                                              'nameLast', 
                                              'weight',
                                              'height', 
                                              'bats', 
                                              'throws' ,
                                              'Seasons', 
                                              'Wins', 
                                              'Losses', 
                                              'Games', 
                                              'Pitch_Starts',
                                              'Complete_Games', 
                                              'Shutouts', 
                                              'Saves', 
                                              'Outs_Pitched', 
                                              'Hits',
                                              'Earned_Runs', 
                                              'Home_Runs', 
                                              'Walks', 
                                              'Strikeouts', 
                                              'Batters_Faced',
                                              'Games_Finished', 
                                              'Runs_Allowed',
                                              'finalGame', 
                                              'Retired_Years', 
                                              'inducted',
                                              'yearID',
                                              ]]

# %%
df_Pitchers_Complete = pd.merge(df_Pitchers_Demo_HOF, df_Clean_Positions, on='playerID', how='left')

# %%
nulls = df_Pitchers_Complete.isnull().sum()
nulls[nulls > 0]
# Out:
# nameFirst           6
# weight            271
# height            233
# bats              409
# throws            213
# finalGame           3
# Retired_Years       3
# inducted         9704
# yearID           9704
# dtype: int64

# %%
# Create Pitchers List by Taking Position Players out of DF
PositionID_list = df_Non_Pitchers.playerID.tolist()
df_Pitchers_final = df_Pitchers_Complete[~df_Pitchers_Complete['playerID'].isin(PositionID_list)]
df_Pitchers_final
# Out:
#         playerID nameFirst  nameLast  weight  height bats throws  Seasons  \
# 0      aardsda01     David   Aardsma   215.0    75.0    R      R        9
# 1       aasedo01       Don      Aase   190.0    75.0    R      R       13
# 2       abadfe01  Fernando      Abad   235.0    74.0    L      L       12
# 3      abbeybe01      Bert     Abbey   175.0    71.0    R      R        7
# 5      abbotco01      Cory    Abbott   210.0    73.0    R      R        1
# ...          ...       ...       ...     ...     ...  ...    ...      ...
# 11295  zuberbi01      Bill     Zuber   195.0    74.0    R      R       13
# 11296  zuberty01     Tyler     Zuber   175.0    71.0    R      R        2
# 11297  zumayjo01      Joel    Zumaya   215.0    75.0    R      R        5
# 11298  zuverge01    George  Zuverink   195.0    76.0    R      R       12
# 11299   zychto01      Tony      Zych   190.0    75.0    R      R        3
#
#        Wins  Losses  ...  FirstBase  SecondBase  ThirdBase  ShortStop  \
# 0        16      18  ...          0           0          0          0
# 1        66      60  ...          0           0          0          0
# 2         8      29  ...          0           0          0          0
# 3        22      40  ...          0           0          0          0
# 5         0       0  ...          0           0          0          0
# ...     ...     ...  ...        ...         ...        ...        ...
# 11295    43      42  ...          0           0          0          0
# 11296     1       5  ...          0           0          0          0
# 11297    13      12  ...          0           0          0          0
# 11298    32      36  ...          0           0          0          0
# 11299     7       3  ...          0           0          0          0
#
#        LeftField  CenterField  RightField  Outfield   DH  Primary_Position
# 0              0            0           0         0  0.0           Pitcher
# 1              0            0           0         0  0.0           Pitcher
# 2              0            0           0         0  0.0           Pitcher
# 3              0            0           0         0  0.0           Pitcher
# 5              0            0           0         0  0.0           Pitcher
# ...          ...          ...         ...       ...  ...               ...
# 11295          0            0           0         0  0.0           Pitcher
# 11296          0            0           0         0  0.0           Pitcher
# 11297          0            0           0         0  0.0           Pitcher
# 11298          0            0           0         0  0.0           Pitcher
# 11299          0            0           0         0  0.0           Pitcher
#
# [10351 rows x 42 columns]

# %%
df_Pitchers_final.columns
# Out:
# Index(['playerID', 'nameFirst', 'nameLast', 'weight', 'height', 'bats',
#        'throws', 'Seasons', 'Wins', 'Losses', 'Games', 'Pitch_Starts',
#        'Complete_Games', 'Shutouts', 'Saves', 'Outs_Pitched', 'Hits',
#        'Earned_Runs', 'Home_Runs', 'Walks', 'Strikeouts', 'Batters_Faced',
#        'Games_Finished', 'Runs_Allowed', 'finalGame', 'Retired_Years',
#        'inducted', 'yearID', 'Total_Games', 'Games_Started', 'Pitcher',
#        'Catcher', 'FirstBase', 'SecondBase', 'ThirdBase', 'ShortStop',
#        'LeftField', 'CenterField', 'RightField', 'Outfield', 'DH',
#        'Primary_Position'],
#       dtype='object')

# %%
df_Pitchers_final = df_Pitchers_final.drop(columns=['Pitcher',
                                                    'Catcher', 
                                                    'FirstBase', 
                                                    'SecondBase', 
                                                    'ThirdBase', 
                                                    'ShortStop',
                                                    'LeftField', 
                                                    'CenterField', 
                                                    'RightField', 
                                                    'Outfield', 
                                                    'DH'])

# %%
df_Pitchers_final.fillna(0, inplace=True)

# %%
df_Pitchers_final.columns
# Out:
# Index(['playerID', 'nameFirst', 'nameLast', 'weight', 'height', 'bats',
#        'throws', 'Seasons', 'Wins', 'Losses', 'Games', 'Pitch_Starts',
#        'Complete_Games', 'Shutouts', 'Saves', 'Outs_Pitched', 'Hits',
#        'Earned_Runs', 'Home_Runs', 'Walks', 'Strikeouts', 'Batters_Faced',
#        'Games_Finished', 'Runs_Allowed', 'finalGame', 'Retired_Years',
#        'inducted', 'yearID', 'Total_Games', 'Games_Started',
#        'Primary_Position'],
#       dtype='object')

# %%
df_Pitchers_final['Hall_Eligible'] = df_Pitchers_final.apply(eligible_for_hall,axis=1)
df_Pitchers_final.inducted.replace(0, 'N', inplace=True)

# %%
df_Pitchers_final
# Out:
#         playerID nameFirst  nameLast  weight  height bats throws  Seasons  \
# 0      aardsda01     David   Aardsma   215.0    75.0    R      R        9
# 1       aasedo01       Don      Aase   190.0    75.0    R      R       13
# 2       abadfe01  Fernando      Abad   235.0    74.0    L      L       12
# 3      abbeybe01      Bert     Abbey   175.0    71.0    R      R        7
# 5      abbotco01      Cory    Abbott   210.0    73.0    R      R        1
# ...          ...       ...       ...     ...     ...  ...    ...      ...
# 11295  zuberbi01      Bill     Zuber   195.0    74.0    R      R       13
# 11296  zuberty01     Tyler     Zuber   175.0    71.0    R      R        2
# 11297  zumayjo01      Joel    Zumaya   215.0    75.0    R      R        5
# 11298  zuverge01    George  Zuverink   195.0    76.0    R      R       12
# 11299   zychto01      Tony      Zych   190.0    75.0    R      R        3
#
#        Wins  Losses  ...  Games_Finished  Runs_Allowed   finalGame  \
# 0        16      18  ...             141           169  2015-08-23
# 1        66      60  ...             235           503  1990-10-03
# 2         8      29  ...             101           155  2021-10-01
# 3        22      40  ...              14           442  1896-09-23
# 5         0       0  ...               2            15  2021-10-02
# ...     ...     ...  ...             ...           ...         ...
# 11295    43      42  ...              90           418  1947-09-23
# 11296     1       5  ...              14            31  2021-09-30
# 11297    13      12  ...              35            80  2010-06-28
# 11298    32      36  ...             139           296  1959-06-15
# 11299     7       3  ...              14            24  2017-08-19
#
#        Retired_Years  inducted  yearID  Total_Games  Games_Started  \
# 0           6.690411         N     0.0          331            0.0
# 1          31.594521         N     0.0          448           91.0
# 2           0.578082         N     0.0          400            6.0
# 3         125.682192         N     0.0           79            0.0
# 5           0.575342         N     0.0            8            1.0
# ...              ...       ...     ...          ...            ...
# 11295      74.652055         N     0.0          224           65.0
# 11296       0.580822         N     0.0           54            0.0
# 11297      11.846575         N     0.0          171            0.0
# 11298      62.917808         N     0.0          266           31.0
# 11299       4.698630         N     0.0           70            1.0
#
#        Primary_Position  Hall_Eligible
# 0               Pitcher   not_eligible
# 1               Pitcher       eligible
# 2               Pitcher   not_eligible
# 3               Pitcher   not_eligible
# 5               Pitcher   not_eligible
# ...                 ...            ...
# 11295           Pitcher       eligible
# 11296           Pitcher   not_eligible
# 11297           Pitcher   not_eligible
# 11298           Pitcher       eligible
# 11299           Pitcher   not_eligible
#
# [10351 rows x 32 columns]

# %%
df_Pitchers_final.playerID.count()
# Out:
# 10351

# %%
df_Pitchers_final = df_Pitchers_final.drop_duplicates(['playerID'])

# %%
df_Pitchers_final.playerID.count()
# Out:
# 9436

# %%
df_Pitchers_final.to_csv('Combined CSV\Pitchers_Complete', index=False)
df_Non_Pitchers.to_csv('Combined CSV\PositionPlayers_Complete', index=False)
