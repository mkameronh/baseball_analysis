# %%
import pandas as pd
import numpy as np

# %%
df_People = pd.read_csv('People.csv', encoding="ISO-8859-1")
df_AllStarFull = pd.read_csv('AllStarFull.csv', encoding="ISO-8859-1")
df_Batting = pd.read_csv('Batting.csv', encoding="ISO-8859-1")
df_Fielding = pd.read_csv('Fielding.csv', encoding="ISO-8859-1")
df_Pitching = pd.read_csv('Pitching.csv', encoding="ISO-8859-1")
df_HOF = pd.read_csv('HallOfFame.csv', encoding= "ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30940/1416547068.py in <module>
# ----> 1 df_People = pd.read_csv('People.csv', encoding="ISO-8859-1")
#       2 df_AllStarFull = pd.read_csv('AllStarFull.csv', encoding="ISO-8859-1")
#       3 df_Batting = pd.read_csv('Batting.csv', encoding="ISO-8859-1")
#       4 df_Fielding = pd.read_csv('Fielding.csv', encoding="ISO-8859-1")
#       5 df_Pitching = pd.read_csv('Pitching.csv', encoding="ISO-8859-1")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_People.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile     2021.0         1.0      22.0  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
df_AllStarFull.head()
# Out:
#     playerID  yearID  gameNum        gameID teamID lgID  GP  startingPos
# 0  gomezle01    1933        0  ALS193307060    NYA   AL   1          1.0
# 1  ferreri01    1933        0  ALS193307060    BOS   AL   1          2.0
# 2  gehrilo01    1933        0  ALS193307060    NYA   AL   1          3.0
# 3  gehrich01    1933        0  ALS193307060    DET   AL   1          4.0
# 4  dykesji01    1933        0  ALS193307060    CHA   AL   1          5.0

# %%
df_Batting.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0  6.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  2.0   2  1.0  NaN  NaN NaN NaN   0.0
#
# [5 rows x 22 columns]

# %%
df_Fielding.head()
# Out:
#     playerID  yearID  stint teamID lgID POS   G    GS  InnOuts  PO   A     E  \
# 0  abercda01    1871      1    TRO  NaN  SS   1   1.0     24.0   1   3   2.0
# 1   addybo01    1871      1    RC1  NaN  2B  22  22.0    606.0  67  72  42.0
# 2   addybo01    1871      1    RC1  NaN  SS   3   3.0     96.0   8  14   7.0
# 3  allisar01    1871      1    CL1  NaN  2B   2   0.0     18.0   1   4   0.0
# 4  allisar01    1871      1    CL1  NaN  OF  29  29.0    729.0  51   3   7.0
#
#    DP  PB  WP  SB  CS  ZR
# 0   0 NaN NaN NaN NaN NaN
# 1   5 NaN NaN NaN NaN NaN
# 2   0 NaN NaN NaN NaN NaN
# 3   0 NaN NaN NaN NaN NaN
# 4   1 NaN NaN NaN NaN NaN

# %%
df_Pitching.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0  bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN   7
# 1  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN   7
# 2  fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN   2
# 3  fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN  20
# 4  fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN   0
#
#    HBP  BK     BFP  GF    R  SH  SF  GIDP
# 0  NaN   0   146.0   0   42 NaN NaN   NaN
# 1  NaN   0  1291.0   0  292 NaN NaN   NaN
# 2  NaN   0    14.0   0    9 NaN NaN   NaN
# 3  NaN   0  1080.0   1  257 NaN NaN   NaN
# 4  NaN   0    57.0   0   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
df_People1980 = df_People[df_People.birthYear > 1980.0] # Born After 1980
df_People1980.head()
# Out:
#      playerID  birthYear  birthMonth  birthDay birthCountry  \
# 0   aardsda01     1981.0        12.0      27.0          USA
# 5    abadfe01     1985.0        12.0      17.0         D.R.
# 10  abbotco01     1995.0         9.0      20.0          USA
# 34  abreual01     1995.0         9.0      26.0         D.R.
# 36  abreubr01     1997.0         4.0      22.0         D.R.
#
#            birthState      birthCity  deathYear  deathMonth  deathDay  ...  \
# 0                  CO         Denver        NaN         NaN       NaN  ...
# 5           La Romana      La Romana        NaN         NaN       NaN  ...
# 10                 CA      San Diego        NaN         NaN       NaN  ...
# 34       Monte Cristi       Guayubin        NaN         NaN       NaN  ...
# 36  Distrito Nacional  Santo Domingo        NaN         NaN       NaN  ...
#
#    nameLast         nameGiven weight height bats throws       debut  \
# 0   Aardsma       David Allan  215.0   75.0    R      R  2004-04-06
# ...

# %%
df_People1980.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
df_People1980.drop(columns=['birthMonth', 'birthDay','birthState', 'birthCity', 'deathCountry',
       'deathYear', 'deathMonth', 'deathDay', 'deathState', 'deathCity',
       'nameFirst', 'nameLast', 'finalGame', 'retroID', 'bbrefID'], axis=1, inplace=True)
# Out:
# C:\Users\nealb\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_People1980.columns
# Out:
# Index(['playerID', 'birthYear', 'birthCountry', 'nameGiven', 'weight',
#        'height', 'bats', 'throws', 'debut'],
#       dtype='object')

# %%
df_People1980.head()
# Out:
#      playerID  birthYear birthCountry         nameGiven  weight  height bats  \
# 0   aardsda01     1981.0          USA       David Allan   215.0    75.0    R
# 5    abadfe01     1985.0         D.R.  Fernando Antonio   235.0    74.0    L
# 10  abbotco01     1995.0          USA        Cory James   210.0    73.0    R
# 34  abreual01     1995.0         D.R.   Albert Enmanuel   190.0    74.0    R
# 36  abreubr01     1997.0         D.R.     Bryan Enrique   225.0    73.0    R
#
#    throws       debut
# 0       R  2004-04-06
# 5       L  2010-07-28
# 10      R  2021-06-05
# 34      R  2020-08-08
# 36      R  2019-07-31

# %%
df_People1980.sort_values(by = 'debut')
# Gives us our cleaning date for the remaining DF (Year > 2000 = '2000-01-01)
# Out:
#         playerID  birthYear birthCountry          nameGiven  weight  height  \
# 20286  zambrca01     1981.0    Venezuela     Carlos Alberto   275.0    76.0
# 1373   betemwi01     1981.0         D.R.             Wilson   220.0    74.0
# 17228  snellch02     1981.0          USA  Christopher Doyle   165.0    70.0
# 14277  perezol01     1981.0       Mexico             Oliver   225.0    75.0
# 14146  peavyja01     1981.0          USA       Jacob Edward   195.0    73.0
# ...          ...        ...          ...                ...     ...     ...
# 4752    dohyky01     1996.0          USA          Kyle Kent   202.0    74.0
# 4019    cruzon01     1998.0         D.R.              Oneil   220.0    79.0
# 123     adonjo01     1998.0         D.R.        Joan Manuel   242.0    74.0
# 14118  paynety01     1992.0          USA      Anthony Tyler   210.0    71.0
# 15716  rojaslu99     1981.0         D.R.            Luis E.   180.0    72.0
#
#       bats throws       debut
# ...
